# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# blue           2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim       2000.0     0.50950     0.500035    0.0     0.00     1.0
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g         2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %%
x=df.iloc[:,:-1]

# %%
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=5)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1600, 20) (400, 20) (1600,) (400,)

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score
dtree = DecisionTreeClassifier()

# %%
drtree=dtree.fit(x_train,y_train)

# %%
dtree.score(x_test,y_test)
# Out:
# 0.845

# %%
predictions=dtree.predict(x_test)

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.845

# %%
dtree.feature_importances_
# Out:
# array([0.11714016, 0.00312515, 0.00356117, 0.        , 0.00411762,
#        0.00549102, 0.00238106, 0.00991203, 0.01049629, 0.00314714,
#        0.01054944, 0.08813985, 0.07760298, 0.64014054, 0.00222233,
#        0.00606595, 0.00437391, 0.00458355, 0.00561642, 0.0013334 ])

# %%
df_feature_importance = pd.DataFrame(dtree.feature_importances_, index=df.columns[0:20], columns=['feature importance']).sort_values('feature importance', ascending=False)
df_feature_importance
# Out:
#                feature importance
# ram                      0.640141
# battery_power            0.117140
# px_height                0.088140
# px_width                 0.077603
# pc                       0.010549
# mobile_wt                0.010496
# m_dep                    0.009912
# sc_w                     0.006066
# touch_screen             0.005616
# four_g                   0.005491
# three_g                  0.004584
# talk_time                0.004374
# fc                       0.004118
# clock_speed              0.003561
# n_cores                  0.003147
# blue                     0.003125
# int_memory               0.002381
# sc_h                     0.002222
# wifi                     0.001333
# dual_sim                 0.000000

# %%
df1=df.drop(['clock_speed','n_cores','blue','int_memory','sc_h','wifi','dual_sim'],axis=1)

# %%
X=df1.iloc[:,:-1]

# %%
Y=df1.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=5)

# %%
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (1600, 13) (400, 13) (1600,) (400,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score
dtree_1 = DecisionTreeClassifier()

# %%
drtree_1=dtree_1.fit(X_train,Y_train)

# %%
dtree_1.score(X_test,Y_test)
# Out:
# 0.865

# %%
predictions=dtree_1.predict(X_test)

# %%
accuracy_score(Y_test,predictions)
# Out:
# 0.865

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(Y_test, predictions)
print(cm)
# Out:
# [[94  9  0  0]
#  [10 78  4  0]
#  [ 0 11 80 10]
#  [ 0  0 10 94]]

# %%
tree.plot_tree(dtree_1)
# Out:
# [Text(165.16368013595167, 209.6742857142857, 'X[8] <= 2231.5\ngini = 0.75\nsamples = 1600\nvalue = [397, 408, 399, 396]'),
#  Text(66.50483383685801, 194.14285714285714, 'X[8] <= 1106.0\ngini = 0.583\nsamples = 841\nvalue = [397, 361, 83, 0]'),
#  Text(34.643202416918434, 178.61142857142858, 'X[6] <= 1449.0\ngini = 0.214\nsamples = 361\nvalue = [317, 44, 0, 0]'),
#  Text(24.78126888217523, 163.07999999999998, 'X[0] <= 1804.5\ngini = 0.156\nsamples = 341\nvalue = [312, 29, 0, 0]'),
#  Text(15.172205438066467, 147.54857142857142, 'X[8] <= 1052.5\ngini = 0.077\nsamples = 300\nvalue = [288, 12, 0, 0]'),
#  Text(8.091842900302115, 132.01714285714286, 'X[0] <= 1329.0\ngini = 0.049\nsamples = 281\nvalue = [274, 7, 0, 0]'),
#  Text(6.0688821752265865, 116.48571428571428, 'gini = 0.0\nsamples = 188\nvalue = [188, 0, 0, 0]'),
#  Text(10.114803625377643, 116.48571428571428, 'X[6] <= 930.0\ngini = 0.139\nsamples = 93\nvalue = [86, 7, 0, 0]'),
# ...

# %%
import pickle

# %%
pickle.dump(drtree_1,open('lr_dtree_2.pkl','wb'))

# %% [markdown]
# #Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()

# %%
logmodel.fit(x_train,y_train)
# Out:
# C:\Users\navna\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logmodel.score(x_test,y_test)
# Out:
# 0.6675
